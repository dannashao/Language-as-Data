# %% [markdown]
# Copyright: Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL

# %% [markdown]
# # Lab 2.3: Linguistic Units

# %% [markdown]
# In this lab, we will take a closer look how to distinguish between words. We use the processed article from the previous lab. **Modify the code to work with all articles from your dataset.**

# %%
import stanza
import pickle

processed_article_file = "../data/processed_data/nlp_article1.pkl"
nlp_output = pickle.load(open(processed_article_file,"rb"))
print(nlp_output)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Les",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Plur|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "start_char": 0,
#       "end_char": 3,
#       "ner": "S-LOC",
#       "multi_ner": [
#         "S-LOC"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "véganeries",
#       "lemma": "véganerie",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 3,
#       "deprel": "nsubj",
#       "start_char": 4,
#       "end_char": 14,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "vont",
#       "lemma": "aller",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 15,
#       "end_char": 19,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 3,
#       "deprel": "advmod",
#       "start_char": 20,
#       "end_char": 22,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "plus",
#       "lemma": "plus",
#       "upos": "ADV",
#       "head": 4,
#       "deprel": "fixed",
#       "start_char": 23,
#       "end_char": 27,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "en",
#       "lemma": "en",
#       "upos": "ADP",
#       "head": 4,
#       "deprel": "fixed",
#       "start_char": 28,
#       "end_char": 30,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "plus",
#       "lemma": "plus",
#       "upos": "ADV",
#       "head": 4,
#       "deprel": "fixed",
#       "start_char": 31,
#       "end_char": 35,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "loin",
#       "lemma": "loin",
#       "upos": "ADV",
#       "head": 3,
#       "deprel": "advmod",
#       "start_char": 36,
#       "end_char": 40,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 3,
#       "deprel": "punct",
#       "start_char": 40,
#       "end_char": 41,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Connaissez",
#       "lemma": "connaître",
#       "upos": "VERB",
#       "feats": "Mood=Imp|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 42,
#       "end_char": 52,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "-vous",
#       "lemma": "vous",
#       "upos": "PRON",
#       "feats": "Emph=No|Number=Plur|Person=2|PronType=Prs",
#       "head": 1,
#       "deprel": "obj",
#       "start_char": 52,
#       "end_char": 57,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "le",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "start_char": 58,
#       "end_char": 60,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "\"",
#       "lemma": "\"",
#       "upos": "PUNCT",
#       "head": 6,
#       "deprel": "punct",
#       "start_char": 61,
#       "end_char": 62,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "faux",
#       "lemma": "faux",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 6,
#       "deprel": "amod",
#       "start_char": 62,
#       "end_char": 66,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "mage",
#       "lemma": "mage",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 1,
#       "deprel": "obj",
#       "start_char": 67,
#       "end_char": 71,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "\"",
#       "lemma": "\"",
#       "upos": "PUNCT",
#       "head": 6,
#       "deprel": "punct",
#       "start_char": 71,
#       "end_char": 72,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "à",
#       "lemma": "à",
#       "upos": "ADP",
#       "head": 9,
#       "deprel": "case",
#       "start_char": 73,
#       "end_char": 74,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "base",
#       "lemma": "base",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 6,
#       "deprel": "nmod",
#       "start_char": 75,
#       "end_char": 79,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 11,
#       "deprel": "case",
#       "start_char": 80,
#       "end_char": 82,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "lait",
#       "lemma": "lait",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 9,
#       "deprel": "nmod",
#       "start_char": 83,
#       "end_char": 87,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 13,
#       "deprel": "case",
#       "start_char": 88,
#       "end_char": 90,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "noix",
#       "lemma": "noix",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 11,
#       "deprel": "nmod",
#       "start_char": 91,
#       "end_char": 95,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 15,
#       "deprel": "case",
#       "start_char": 96,
#       "end_char": 98,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "cajou",
#       "lemma": "cajou",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 13,
#       "deprel": "nmod",
#       "start_char": 99,
#       "end_char": 104,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "?",
#       "lemma": "?",
#       "upos": "PUNCT",
#       "head": 6,
#       "deprel": "punct",
#       "start_char": 105,
#       "end_char": 106,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "...",
#       "lemma": "...",
#       "upos": "PUNCT",
#       "head": 18,
#       "deprel": "punct",
#       "start_char": 107,
#       "end_char": 110,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "Article",
#       "lemma": "article",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 6,
#       "deprel": "appos",
#       "start_char": 111,
#       "end_char": 118,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "sans",
#       "lemma": "sans",
#       "upos": "ADP",
#       "head": 20,
#       "deprel": "case",
#       "start_char": 119,
#       "end_char": 123,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "intérêt",
#       "lemma": "intérêt",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 18,
#       "deprel": "nmod",
#       "start_char": 124,
#       "end_char": 131,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 21,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 1,
#       "deprel": "punct",
#       "start_char": 131,
#       "end_char": 132,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Oui",
#       "lemma": "oui",
#       "upos": "INTJ",
#       "head": 4,
#       "deprel": "discourse",
#       "start_char": 133,
#       "end_char": 136,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "le",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 3,
#       "deprel": "det",
#       "start_char": 137,
#       "end_char": 139,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "faux-mage",
#       "lemma": "faux-mage",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 4,
#       "deprel": "nsubj",
#       "start_char": 140,
#       "end_char": 149,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "existe",
#       "lemma": "exister",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 150,
#       "end_char": 156,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "head": 6,
#       "deprel": "cc",
#       "start_char": 157,
#       "end_char": 159,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "alors",
#       "lemma": "alors",
#       "upos": "ADV",
#       "head": 4,
#       "deprel": "conj",
#       "start_char": 160,
#       "end_char": 165,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "?",
#       "lemma": "?",
#       "upos": "PUNCT",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 166,
#       "end_char": 167,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Oui",
#       "lemma": "oui",
#       "upos": "INTJ",
#       "head": 4,
#       "deprel": "discourse",
#       "start_char": 168,
#       "end_char": 171,
#       "ner": "S-LOC",
#       "multi_ner": [
#         "S-LOC"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "il",
#       "lemma": "lui",
#       "upos": "PRON",
#       "feats": "Emph=No|Gender=Masc|Number=Sing|Person=3|PronType=Prs",
#       "head": 4,
#       "deprel": "expl:subj",
#       "start_char": 172,
#       "end_char": 174,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "y",
#       "lemma": "y",
#       "upos": "PRON",
#       "feats": "Emph=No|Person=3|PronType=Prs",
#       "head": 4,
#       "deprel": "expl:comp",
#       "start_char": 175,
#       "end_char": 176,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "a",
#       "lemma": "avoir",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 177,
#       "end_char": 178,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "des",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Number=Plur|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "start_char": 179,
#       "end_char": 182,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "simili",
#       "lemma": "simili",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 4,
#       "deprel": "obj",
#       "start_char": 183,
#       "end_char": 189,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "comme",
#       "lemma": "comme",
#       "upos": "ADP",
#       "head": 9,
#       "deprel": "case",
#       "start_char": 190,
#       "end_char": 195,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "le",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 9,
#       "deprel": "det",
#       "start_char": 196,
#       "end_char": 198,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "lait",
#       "lemma": "lait",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 6,
#       "deprel": "nmod",
#       "start_char": 199,
#       "end_char": 203,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "d'",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 11,
#       "deprel": "case",
#       "start_char": 204,
#       "end_char": 206,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "amande",
#       "lemma": "amande",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 9,
#       "deprel": "nmod",
#       "start_char": 206,
#       "end_char": 212,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 14,
#       "deprel": "punct",
#       "start_char": 212,
#       "end_char": 213,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "des",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Number=Plur|PronType=Art",
#       "head": 14,
#       "deprel": "det",
#       "start_char": 214,
#       "end_char": 217,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "steak",
#       "lemma": "steak",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 9,
#       "deprel": "conj",
#       "start_char": 218,
#       "end_char": 223,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 16,
#       "deprel": "case",
#       "start_char": 224,
#       "end_char": 226,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "soja",
#       "lemma": "soja",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 14,
#       "deprel": "nmod",
#       "start_char": 227,
#       "end_char": 231,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "head": 18,
#       "deprel": "cc",
#       "start_char": 232,
#       "end_char": 234,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "alors",
#       "lemma": "alors",
#       "upos": "ADV",
#       "head": 9,
#       "deprel": "conj",
#       "start_char": 235,
#       "end_char": 240,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "?",
#       "lemma": "?",
#       "upos": "PUNCT",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 241,
#       "end_char": 242,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Tu",
#       "lemma": "toi",
#       "upos": "PRON",
#       "feats": "Emph=No|Number=Sing|Person=2|PronType=Prs",
#       "head": 2,
#       "deprel": "nsubj",
#       "start_char": 243,
#       "end_char": 245,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "veux",
#       "lemma": "vouloir",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 246,
#       "end_char": 250,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "pas",
#       "lemma": "pas",
#       "upos": "ADV",
#       "feats": "Polarity=Neg",
#       "head": 2,
#       "deprel": "advmod",
#       "start_char": 251,
#       "end_char": 254,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "en",
#       "lemma": "en",
#       "upos": "PRON",
#       "feats": "Emph=No|Person=3|PronType=Prs",
#       "head": 5,
#       "deprel": "iobj",
#       "start_char": 255,
#       "end_char": 257,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "manger",
#       "lemma": "manger",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 2,
#       "deprel": "xcomp",
#       "start_char": 258,
#       "end_char": 264,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 10,
#       "deprel": "punct",
#       "start_char": 264,
#       "end_char": 265,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "personne",
#       "lemma": "personne",
#       "upos": "PRON",
#       "feats": "Gender=Masc|Number=Sing|PronType=Neg",
#       "head": 10,
#       "deprel": "nsubj",
#       "start_char": 266,
#       "end_char": 274,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "t'",
#       "lemma": "toi",
#       "upos": "PRON",
#       "feats": "Emph=No|Number=Sing|Person=2|PronType=Prs",
#       "head": 10,
#       "deprel": "obj",
#       "start_char": 275,
#       "end_char": 277,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "y",
#       "lemma": "y",
#       "upos": "PRON",
#       "feats": "Emph=No|Person=3|PronType=Prs",
#       "head": 10,
#       "deprel": "iobj",
#       "start_char": 277,
#       "end_char": 278,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "oblige",
#       "lemma": "obliger",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 2,
#       "deprel": "conj",
#       "start_char": 279,
#       "end_char": 285,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 2,
#       "deprel": "punct",
#       "start_char": 285,
#       "end_char": 286,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Critiquer",
#       "lemma": "critiquer",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 14,
#       "deprel": "advcl",
#       "start_char": 287,
#       "end_char": 296,
#       "ner": "S-MISC",
#       "multi_ner": [
#         "S-MISC"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "l'",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Sing|PronType=Art",
#       "head": 3,
#       "deprel": "det",
#       "start_char": 297,
#       "end_char": 299,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "existence",
#       "lemma": "existence",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 1,
#       "deprel": "obj",
#       "start_char": 299,
#       "end_char": 308,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 5,
#       "deprel": "case",
#       "start_char": 309,
#       "end_char": 311,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "produits",
#       "lemma": "produit",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 3,
#       "deprel": "nmod",
#       "start_char": 312,
#       "end_char": 320,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "head": 8,
#       "deprel": "cc",
#       "start_char": 321,
#       "end_char": 323,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "en",
#       "lemma": "en",
#       "upos": "PRON",
#       "feats": "Emph=No|Person=3|PronType=Prs",
#       "head": 8,
#       "deprel": "expl:comp",
#       "start_char": 324,
#       "end_char": 326,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "vouloir",
#       "lemma": "vouloir",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 1,
#       "deprel": "conj",
#       "start_char": 327,
#       "end_char": 334,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         9,
#         10
#       ],
#       "text": "au",
#       "start_char": 335,
#       "end_char": 337,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "à",
#       "lemma": "à",
#       "upos": "ADP",
#       "head": 11,
#       "deprel": "case"
#     },
#     {
#       "id": 10,
#       "text": "le",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 11,
#       "deprel": "det"
#     },
#     {
#       "id": 11,
#       "text": "vegan",
#       "lemma": "vegan",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 8,
#       "deprel": "obl:arg",
#       "start_char": 338,
#       "end_char": 343,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "ça",
#       "lemma": "ça",
#       "upos": "PRON",
#       "feats": "Gender=Masc|Number=Sing|Person=3|PronType=Dem",
#       "head": 14,
#       "deprel": "nsubj",
#       "start_char": 344,
#       "end_char": 346,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "vous",
#       "lemma": "vous",
#       "upos": "PRON",
#       "feats": "Emph=No|Number=Plur|Person=2|PronType=Prs",
#       "head": 14,
#       "deprel": "obj",
#       "start_char": 347,
#       "end_char": 351,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "avance",
#       "lemma": "avancer",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 352,
#       "end_char": 358,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "à",
#       "lemma": "à",
#       "upos": "ADP",
#       "head": 16,
#       "deprel": "case",
#       "start_char": 359,
#       "end_char": 360,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "quoi",
#       "lemma": "quoi",
#       "upos": "PRON",
#       "feats": "PronType=Int",
#       "head": 14,
#       "deprel": "obl:arg",
#       "start_char": 361,
#       "end_char": 365,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "?",
#       "lemma": "?",
#       "upos": "PUNCT",
#       "head": 14,
#       "deprel": "punct",
#       "start_char": 366,
#       "end_char": 367,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "C'",
#       "lemma": "ce",
#       "upos": "PRON",
#       "feats": "Gender=Masc|Number=Sing|Person=3|PronType=Dem",
#       "head": 3,
#       "deprel": "expl:subj",
#       "start_char": 368,
#       "end_char": 370,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "est",
#       "lemma": "être",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 3,
#       "deprel": "cop",
#       "start_char": 370,
#       "end_char": 373,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "vous",
#       "lemma": "vous",
#       "upos": "PRON",
#       "feats": "Emph=No|Number=Plur|Person=2|PronType=Prs",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 374,
#       "end_char": 378,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "qui",
#       "lemma": "qui",
#       "upos": "PRON",
#       "feats": "PronType=Rel",
#       "head": 6,
#       "deprel": "nsubj",
#       "start_char": 379,
#       "end_char": 382,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "êtes",
#       "lemma": "être",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin",
#       "head": 6,
#       "deprel": "cop",
#       "start_char": 383,
#       "end_char": 387,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "intolérant",
#       "lemma": "intolérant",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 3,
#       "deprel": "advcl:cleft",
#       "start_char": 388,
#       "end_char": 398,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "là",
#       "lemma": "là",
#       "upos": "ADV",
#       "head": 6,
#       "deprel": "advmod",
#       "start_char": 399,
#       "end_char": 401,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "...",
#       "lemma": "...",
#       "upos": "PUNCT",
#       "head": 3,
#       "deprel": "punct",
#       "start_char": 401,
#       "end_char": 404,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Être",
#       "lemma": "être",
#       "upos": "AUX",
#       "feats": "VerbForm=Inf",
#       "head": 4,
#       "deprel": "advcl",
#       "start_char": 405,
#       "end_char": 409,
#       "ner": "S-MISC",
#       "multi_ner": [
#         "S-MISC"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "vegan",
#       "lemma": "vegan",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 1,
#       "deprel": "xcomp",
#       "start_char": 410,
#       "end_char": 415,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "ça",
#       "lemma": "ça",
#       "upos": "PRON",
#       "feats": "Gender=Masc|Number=Sing|Person=3|PronType=Dem",
#       "head": 4,
#       "deprel": "nsubj",
#       "start_char": 416,
#       "end_char": 418,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "veut",
#       "lemma": "vouloir",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 419,
#       "end_char": 423,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "juste",
#       "lemma": "juste",
#       "upos": "ADV",
#       "head": 4,
#       "deprel": "advmod",
#       "start_char": 424,
#       "end_char": 429,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "dire",
#       "lemma": "dire",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 4,
#       "deprel": "xcomp",
#       "start_char": 430,
#       "end_char": 434,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "boycotter",
#       "lemma": "boycotter",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 6,
#       "deprel": "xcomp",
#       "start_char": 435,
#       "end_char": 444,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "l'",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Sing|PronType=Art",
#       "head": 9,
#       "deprel": "det",
#       "start_char": 445,
#       "end_char": 447,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "utilisation",
#       "lemma": "utilisation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 7,
#       "deprel": "obj",
#       "start_char": 447,
#       "end_char": 458,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         10,
#         11
#       ],
#       "text": "des",
#       "start_char": 459,
#       "end_char": 462,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 12,
#       "deprel": "case"
#     },
#     {
#       "id": 11,
#       "text": "les",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Plur|PronType=Art",
#       "head": 12,
#       "deprel": "det"
#     },
#     {
#       "id": 12,
#       "text": "animaux",
#       "lemma": "animal",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 9,
#       "deprel": "nmod",
#       "start_char": 463,
#       "end_char": 470,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 15,
#       "deprel": "punct",
#       "start_char": 470,
#       "end_char": 471,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "la",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 15,
#       "deprel": "det",
#       "start_char": 472,
#       "end_char": 474,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "maltraitance",
#       "lemma": "maltraitance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 9,
#       "deprel": "conj",
#       "start_char": 475,
#       "end_char": 487,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "animale",
#       "lemma": "animal",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 15,
#       "deprel": "amod",
#       "start_char": 488,
#       "end_char": 495,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "ect",
#       "lemma": "ect",
#       "upos": "INTJ",
#       "head": 4,
#       "deprel": "discourse",
#       "start_char": 496,
#       "end_char": 499,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 499,
#       "end_char": 500,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "L'",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Sing|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "start_char": 501,
#       "end_char": 503,
#       "ner": "B-MISC",
#       "multi_ner": [
#         "B-MISC"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "Homme",
#       "lemma": "homme",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 6,
#       "deprel": "nsubj",
#       "start_char": 503,
#       "end_char": 508,
#       "ner": "E-MISC",
#       "multi_ner": [
#         "E-MISC"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "est",
#       "lemma": "être",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 6,
#       "deprel": "cop",
#       "start_char": 509,
#       "end_char": 512,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "aussi",
#       "lemma": "aussi",
#       "upos": "ADV",
#       "head": 6,
#       "deprel": "advmod",
#       "start_char": 513,
#       "end_char": 518,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "un",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "start_char": 519,
#       "end_char": 521,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "animal",
#       "lemma": "animal",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 522,
#       "end_char": 528,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "donc",
#       "lemma": "donc",
#       "upos": "CCONJ",
#       "head": 14,
#       "deprel": "cc",
#       "start_char": 529,
#       "end_char": 533,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "une",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 10,
#       "deprel": "det",
#       "start_char": 534,
#       "end_char": 537,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "bonne",
#       "lemma": "bon",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 10,
#       "deprel": "amod",
#       "start_char": 538,
#       "end_char": 543,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "partie",
#       "lemma": "partie",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 14,
#       "deprel": "nsubj",
#       "start_char": 544,
#       "end_char": 550,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         11,
#         12
#       ],
#       "text": "des",
#       "start_char": 551,
#       "end_char": 554,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 13,
#       "deprel": "case"
#     },
#     {
#       "id": 12,
#       "text": "les",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Plur|PronType=Art",
#       "head": 13,
#       "deprel": "det"
#     },
#     {
#       "id": 13,
#       "text": "vegans",
#       "lemma": "vegan",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 10,
#       "deprel": "nmod",
#       "start_char": 555,
#       "end_char": 561,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "font",
#       "lemma": "faire",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 6,
#       "deprel": "conj",
#       "start_char": 562,
#       "end_char": 566,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "attention",
#       "lemma": "attention",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 14,
#       "deprel": "obj:lvc",
#       "start_char": 567,
#       "end_char": 576,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "à",
#       "lemma": "à",
#       "upos": "ADP",
#       "head": 18,
#       "deprel": "case",
#       "start_char": 577,
#       "end_char": 578,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "la",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 18,
#       "deprel": "det",
#       "start_char": 579,
#       "end_char": 581,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "provenance",
#       "lemma": "provenance",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 15,
#       "deprel": "obl:arg",
#       "start_char": 582,
#       "end_char": 592,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 21,
#       "deprel": "case",
#       "start_char": 593,
#       "end_char": 595,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "leur",
#       "lemma": "son",
#       "upos": "DET",
#       "feats": "Number=Sing|Number[psor]=Plur|Person[psor]=3|Poss=Yes|PronType=Prs",
#       "head": 21,
#       "deprel": "det",
#       "start_char": 596,
#       "end_char": 600,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "produits",
#       "lemma": "produit",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 18,
#       "deprel": "nmod",
#       "start_char": 601,
#       "end_char": 609,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "head": 24,
#       "deprel": "cc",
#       "start_char": 610,
#       "end_char": 612,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 23,
#       "text": "ne",
#       "lemma": "ne",
#       "upos": "ADV",
#       "feats": "Polarity=Neg",
#       "head": 24,
#       "deprel": "advmod",
#       "start_char": 613,
#       "end_char": 615,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 24,
#       "text": "vont",
#       "lemma": "aller",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 14,
#       "deprel": "conj",
#       "start_char": 616,
#       "end_char": 620,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 25,
#       "text": "pas",
#       "lemma": "pas",
#       "upos": "ADV",
#       "feats": "Polarity=Neg",
#       "head": 24,
#       "deprel": "advmod",
#       "start_char": 621,
#       "end_char": 624,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 26,
#       "text": "acheter",
#       "lemma": "acheter",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 24,
#       "deprel": "xcomp",
#       "start_char": 625,
#       "end_char": 632,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 27,
#       "text": "de",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Number=Plur|PronType=Art",
#       "head": 28,
#       "deprel": "det",
#       "start_char": 633,
#       "end_char": 635,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 28,
#       "text": "noix",
#       "lemma": "noix",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 26,
#       "deprel": "obj",
#       "start_char": 636,
#       "end_char": 640,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 29,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 30,
#       "deprel": "case",
#       "start_char": 641,
#       "end_char": 643,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 30,
#       "text": "cajou",
#       "lemma": "cajou",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 28,
#       "deprel": "nmod",
#       "start_char": 644,
#       "end_char": 649,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 31,
#       "text": "indienne",
#       "lemma": "indien",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 30,
#       "deprel": "amod",
#       "start_char": 650,
#       "end_char": 658,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 32,
#       "text": "ou",
#       "lemma": "ou",
#       "upos": "CCONJ",
#       "head": 34,
#       "deprel": "cc",
#       "start_char": 659,
#       "end_char": 661,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 33,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 34,
#       "deprel": "case",
#       "start_char": 662,
#       "end_char": 664,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 34,
#       "text": "produits",
#       "lemma": "produit",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 30,
#       "deprel": "conj",
#       "start_char": 665,
#       "end_char": 673,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 35,
#       "text": "qui",
#       "lemma": "qui",
#       "upos": "PRON",
#       "feats": "PronType=Rel",
#       "head": 37,
#       "deprel": "nsubj",
#       "start_char": 674,
#       "end_char": 677,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 36,
#       "text": "en",
#       "lemma": "en",
#       "upos": "PRON",
#       "feats": "Emph=No|Person=3|PronType=Prs",
#       "head": 37,
#       "deprel": "iobj",
#       "start_char": 678,
#       "end_char": 680,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 37,
#       "text": "contiennent",
#       "lemma": "contenir",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 34,
#       "deprel": "acl:relcl",
#       "start_char": 681,
#       "end_char": 692,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 38,
#       "text": "pour",
#       "lemma": "pour",
#       "upos": "ADP",
#       "head": 39,
#       "deprel": "mark",
#       "start_char": 693,
#       "end_char": 697,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 39,
#       "text": "boycotter",
#       "lemma": "boycotter",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 37,
#       "deprel": "advcl",
#       "start_char": 698,
#       "end_char": 707,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 40,
#       "text": "l'",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Sing|PronType=Art",
#       "head": 41,
#       "deprel": "det",
#       "start_char": 708,
#       "end_char": 710,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 41,
#       "text": "esclavage",
#       "lemma": "esclavage",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 39,
#       "deprel": "obj",
#       "start_char": 710,
#       "end_char": 719,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 42,
#       "text": "moderne",
#       "lemma": "moderne",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 41,
#       "deprel": "amod",
#       "start_char": 720,
#       "end_char": 727,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 43,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 6,
#       "deprel": "punct",
#       "start_char": 727,
#       "end_char": 728,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Je",
#       "lemma": "moi",
#       "upos": "PRON",
#       "feats": "Emph=No|Number=Sing|Person=1|PronType=Prs",
#       "head": 2,
#       "deprel": "nsubj",
#       "start_char": 729,
#       "end_char": 731,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "rappelle",
#       "lemma": "rappeler",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 732,
#       "end_char": 740,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "que",
#       "lemma": "que",
#       "upos": "SCONJ",
#       "head": 10,
#       "deprel": "mark",
#       "start_char": 741,
#       "end_char": 744,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "les",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Plur|PronType=Art",
#       "head": 5,
#       "deprel": "det",
#       "start_char": 745,
#       "end_char": 748,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "produits",
#       "lemma": "produit",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 10,
#       "deprel": "nsubj",
#       "start_char": 749,
#       "end_char": 757,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "vegans",
#       "lemma": "vegan",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 5,
#       "deprel": "amod",
#       "start_char": 758,
#       "end_char": 764,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "sont",
#       "lemma": "être",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 10,
#       "deprel": "cop",
#       "start_char": 765,
#       "end_char": 769,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "majoritairement",
#       "lemma": "majoritairement",
#       "upos": "ADV",
#       "head": 10,
#       "deprel": "advmod",
#       "start_char": 770,
#       "end_char": 785,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "des",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Number=Plur|PronType=Art",
#       "head": 10,
#       "deprel": "det",
#       "start_char": 786,
#       "end_char": 789,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "légumes",
#       "lemma": "légume",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 2,
#       "deprel": "ccomp",
#       "start_char": 790,
#       "end_char": 797,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "et",
#       "lemma": "et",
#       "upos": "CCONJ",
#       "head": 13,
#       "deprel": "cc",
#       "start_char": 798,
#       "end_char": 800,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "des",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Number=Plur|PronType=Art",
#       "head": 13,
#       "deprel": "det",
#       "start_char": 801,
#       "end_char": 804,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "fruits",
#       "lemma": "fruit",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 10,
#       "deprel": "conj",
#       "start_char": 805,
#       "end_char": 811,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "indispensable",
#       "lemma": "indispensable",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 10,
#       "deprel": "amod",
#       "start_char": 812,
#       "end_char": 825,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "à",
#       "lemma": "à",
#       "upos": "ADP",
#       "head": 17,
#       "deprel": "case",
#       "start_char": 826,
#       "end_char": 827,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "notre",
#       "lemma": "son",
#       "upos": "DET",
#       "feats": "Number=Sing|Number[psor]=Plur|Person[psor]=1|Poss=Yes|PronType=Prs",
#       "head": 17,
#       "deprel": "det",
#       "start_char": 828,
#       "end_char": 833,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "santé",
#       "lemma": "santé",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 14,
#       "deprel": "obl:arg",
#       "start_char": 834,
#       "end_char": 839,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "à",
#       "lemma": "à",
#       "upos": "ADP",
#       "head": 19,
#       "deprel": "case",
#       "start_char": 840,
#       "end_char": 841,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "tous",
#       "lemma": "tout",
#       "upos": "PRON",
#       "feats": "Gender=Masc|Number=Plur|Person=3|PronType=Ind",
#       "head": 14,
#       "deprel": "obl:arg",
#       "start_char": 842,
#       "end_char": 846,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 2,
#       "deprel": "punct",
#       "start_char": 846,
# ...
#       "head": 12,
#       "deprel": "conj",
#       "start_char": 3398,
#       "end_char": 3404,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 25,
#       "text": "l'",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Sing|PronType=Art",
#       "head": 26,
#       "deprel": "det",
#       "start_char": 3405,
#       "end_char": 3407,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 26,
#       "text": "image",
#       "lemma": "image",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 24,
#       "deprel": "obj",
#       "start_char": 3407,
#       "end_char": 3412,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 27,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 29,
#       "deprel": "case",
#       "start_char": 3413,
#       "end_char": 3415,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 28,
#       "text": "votre",
#       "lemma": "son",
#       "upos": "DET",
#       "feats": "Number=Sing|Number[psor]=Plur|Person[psor]=2|Poss=Yes|PronType=Prs",
#       "head": 29,
#       "deprel": "det",
#       "start_char": 3416,
#       "end_char": 3421,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 29,
#       "text": "insertitude",
#       "lemma": "insertitude",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 26,
#       "deprel": "nmod",
#       "start_char": 3422,
#       "end_char": 3433,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 30,
#       "text": "?",
#       "lemma": "?",
#       "upos": "PUNCT",
#       "head": 1,
#       "deprel": "punct",
#       "start_char": 3434,
#       "end_char": 3435,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Je",
#       "lemma": "moi",
#       "upos": "PRON",
#       "feats": "Emph=No|Number=Sing|Person=1|PronType=Prs",
#       "head": 4,
#       "deprel": "nsubj",
#       "start_char": 3436,
#       "end_char": 3438,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "suis",
#       "lemma": "être",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin",
#       "head": 4,
#       "deprel": "cop",
#       "start_char": 3439,
#       "end_char": 3443,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "un",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 4,
#       "deprel": "det",
#       "start_char": 3444,
#       "end_char": 3446,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "carnivore",
#       "lemma": "carnivore",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 3447,
#       "end_char": 3456,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "convaincu",
#       "lemma": "convaincre",
#       "upos": "VERB",
#       "feats": "Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 4,
#       "deprel": "acl",
#       "start_char": 3457,
#       "end_char": 3466,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 20,
#       "deprel": "punct",
#       "start_char": 3466,
#       "end_char": 3467,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "mais",
#       "lemma": "mais",
#       "upos": "CCONJ",
#       "head": 20,
#       "deprel": "cc",
#       "start_char": 3468,
#       "end_char": 3472,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "alors",
#       "lemma": "alors",
#       "upos": "ADV",
#       "head": 20,
#       "deprel": "advmod",
#       "start_char": 3473,
#       "end_char": 3478,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "quand",
#       "lemma": "quand",
#       "upos": "SCONJ",
#       "head": 11,
#       "deprel": "mark",
#       "start_char": 3479,
#       "end_char": 3484,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "je",
#       "lemma": "moi",
#       "upos": "PRON",
#       "feats": "Emph=No|Number=Sing|Person=1|PronType=Prs",
#       "head": 11,
#       "deprel": "nsubj",
#       "start_char": 3485,
#       "end_char": 3487,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "vois",
#       "lemma": "voir",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin",
#       "head": 20,
#       "deprel": "advcl",
#       "start_char": 3488,
#       "end_char": 3492,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "le",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 13,
#       "deprel": "det",
#       "start_char": 3493,
#       "end_char": 3495,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "niveau",
#       "lemma": "niveau",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 11,
#       "deprel": "obj",
#       "start_char": 3496,
#       "end_char": 3502,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         14,
#         15
#       ],
#       "text": "des",
#       "start_char": 3503,
#       "end_char": 3506,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 16,
#       "deprel": "case"
#     },
#     {
#       "id": 15,
#       "text": "les",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Plur|PronType=Art",
#       "head": 16,
#       "deprel": "det"
#     },
#     {
#       "id": 16,
#       "text": "commentaires",
#       "lemma": "commentaire",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 13,
#       "deprel": "nmod",
#       "start_char": 3507,
#       "end_char": 3519,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 11,
#       "deprel": "punct",
#       "start_char": 3519,
#       "end_char": 3520,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "les",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Plur|PronType=Art",
#       "head": 19,
#       "deprel": "det",
#       "start_char": 3521,
#       "end_char": 3524,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "vegans",
#       "lemma": "vegan",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 20,
#       "deprel": "nsubj",
#       "start_char": 3525,
#       "end_char": 3531,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "doivent",
#       "lemma": "devoir",
#       "upos": "VERB",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 4,
#       "deprel": "conj",
#       "start_char": 3532,
#       "end_char": 3539,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "bien",
#       "lemma": "bien",
#       "upos": "ADV",
#       "head": 20,
#       "deprel": "advmod",
#       "start_char": 3540,
#       "end_char": 3544,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "nous",
#       "lemma": "nous",
#       "upos": "PRON",
#       "feats": "Emph=No|Number=Plur|Person=1|PronType=Prs",
#       "head": 23,
#       "deprel": "obj",
#       "start_char": 3545,
#       "end_char": 3549,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 23,
#       "text": "prendre",
#       "lemma": "prendre",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 20,
#       "deprel": "xcomp",
#       "start_char": 3550,
#       "end_char": 3557,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 24,
#       "text": "pour",
#       "lemma": "pour",
#       "upos": "ADP",
#       "head": 26,
#       "deprel": "case",
#       "start_char": 3558,
#       "end_char": 3562,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 25,
#       "text": "des",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Number=Plur|PronType=Art",
#       "head": 26,
#       "deprel": "det",
#       "start_char": 3563,
#       "end_char": 3566,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 26,
#       "text": "c...",
#       "lemma": "c...",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 23,
#       "deprel": "obl:mod",
#       "start_char": 3567,
#       "end_char": 3571,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 27,
#       "text": "arriérés",
#       "lemma": "arriéré",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Plur",
#       "head": 26,
#       "deprel": "amod",
#       "start_char": 3572,
#       "end_char": 3580,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 28,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 3580,
#       "end_char": 3581,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Il",
#       "lemma": "lui",
#       "upos": "PRON",
#       "feats": "Emph=No|Gender=Masc|Number=Sing|Person=3|PronType=Prs",
#       "head": 4,
#       "deprel": "expl:subj",
#       "start_char": 3582,
#       "end_char": 3584,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "est",
#       "lemma": "être",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 4,
#       "deprel": "cop",
#       "start_char": 3585,
#       "end_char": 3588,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "assez",
#       "lemma": "assez",
#       "upos": "ADV",
#       "head": 4,
#       "deprel": "advmod",
#       "start_char": 3589,
#       "end_char": 3594,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "facile",
#       "lemma": "facile",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 3595,
#       "end_char": 3601,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 6,
#       "deprel": "mark",
#       "start_char": 3602,
#       "end_char": 3604,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "trouver",
#       "lemma": "trouver",
#       "upos": "VERB",
#       "feats": "VerbForm=Inf",
#       "head": 4,
#       "deprel": "csubj",
#       "start_char": 3605,
#       "end_char": 3612,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "des",
#       "lemma": "un",
#       "upos": "DET",
#       "feats": "Definite=Ind|Number=Plur|PronType=Art",
#       "head": 8,
#       "deprel": "det",
#       "start_char": 3613,
#       "end_char": 3616,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "contradictions",
#       "lemma": "contradiction",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 6,
#       "deprel": "obj",
#       "start_char": 3617,
#       "end_char": 3631,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "dans",
#       "lemma": "dans",
#       "upos": "ADP",
#       "head": 11,
#       "deprel": "case",
#       "start_char": 3632,
#       "end_char": 3636,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "la",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 11,
#       "deprel": "det",
#       "start_char": 3637,
#       "end_char": 3639,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "plupart",
#       "lemma": "plupart",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 6,
#       "deprel": "obl:mod",
#       "start_char": 3640,
#       "end_char": 3647,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         12,
#         13
#       ],
#       "text": "des",
#       "start_char": 3648,
#       "end_char": 3651,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 14,
#       "deprel": "case"
#     },
#     {
#       "id": 13,
#       "text": "les",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Plur|PronType=Art",
#       "head": 14,
#       "deprel": "det"
#     },
#     {
#       "id": 14,
#       "text": "argumentations",
#       "lemma": "argumentation",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 11,
#       "deprel": "nmod",
#       "start_char": 3652,
#       "end_char": 3666,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "veganes",
#       "lemma": "vegan",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 14,
#       "deprel": "amod",
#       "start_char": 3667,
#       "end_char": 3674,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 21,
#       "deprel": "punct",
#       "start_char": 3674,
#       "end_char": 3675,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "mais",
#       "lemma": "mais",
#       "upos": "CCONJ",
#       "head": 21,
#       "deprel": "cc",
#       "start_char": 3676,
#       "end_char": 3680,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "alors",
#       "lemma": "alors",
#       "upos": "ADV",
#       "head": 21,
#       "deprel": "advmod",
#       "start_char": 3681,
#       "end_char": 3686,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "dans",
#       "lemma": "dans",
#       "upos": "ADP",
#       "head": 21,
#       "deprel": "case",
#       "start_char": 3687,
#       "end_char": 3691,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "les",
#       "lemma": "le",
#       "upos": "DET",
#       "feats": "Definite=Def|Number=Plur|PronType=Art",
#       "head": 21,
#       "deprel": "det",
#       "start_char": 3692,
#       "end_char": 3695,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "votre",
#       "lemma": "son",
#       "upos": "DET",
#       "feats": "Number=Sing|Number[psor]=Plur|Person[psor]=2|Poss=Yes|PronType=Prs",
#       "head": 11,
#       "deprel": "conj",
#       "start_char": 3696,
#       "end_char": 3701,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "...",
#       "lemma": "...",
#       "upos": "PUNCT",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 3701,
#       "end_char": 3704,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ]
# ]

# %% [markdown]
# ## 1. Tokens vs Lemmas

# %% [markdown]
# In the HLT course, you already learned about the difference between tokens and lemmas. Let's take a look at the difference.
#
# It depends on the language you work with and on your analysis goal whether you are more interested in tokens or in lemmas. **Think about some examples.**

# %%
for i, sentence in enumerate(nlp_output.sentences):
    # Only check first 20 sentences
    if i==20:
        break
        
    print(str(i), sentence.text)
    for word in sentence.words:
        if not word.text == word.lemma:
            print(word.id, word.text, word.lemma)
    print()
# Out:
# 0 Les véganeries vont de plus en plus loin.
# 1 Les le
# 2 véganeries véganerie
# 3 vont aller
#
# 1 Connaissez-vous le "faux mage" à base de lait de noix de cajou ? ... Article sans intérêt.
# 1 Connaissez connaître
# 2 -vous vous
# 18 Article article
#
# 2 Oui le faux-mage existe et alors ?
# 1 Oui oui
# 4 existe exister
#
# 3 Oui il y a des simili comme le lait d'amande, des steak de soja et alors ?
# 1 Oui oui
# 2 il lui
# 4 a avoir
# 5 des un
# 10 d' de
# 13 des un
#
# 4 Tu veux pas en manger, personne t'y oblige.
# 1 Tu toi
# 2 veux vouloir
# 8 t' toi
# 10 oblige obliger
#
# 5 Critiquer l'existence de produits et en vouloir au vegan ça vous avance à quoi ?
# 1 Critiquer critiquer
# 2 l' le
# 5 produits produit
# 14 avance avancer
#
# 6 C'est vous qui êtes intolérant là...
# 1 C' ce
# 2 est être
# 5 êtes être
#
# 7 Être vegan ça veut juste dire boycotter l'utilisation des animaux, la maltraitance animale ect.
# 1 Être être
# 4 veut vouloir
# 8 l' le
# 11 les le
# 12 animaux animal
# 14 la le
# 16 animale animal
#
# 8 L'Homme est aussi un animal donc une bonne partie des vegans font attention à la provenance de leur produits et ne vont pas acheter de noix de cajou indienne ou de produits qui en contiennent pour boycotter l'esclavage moderne.
# 1 L' le
# 2 Homme homme
# 3 est être
# 8 une un
# 9 bonne bon
# 12 les le
# 13 vegans vegan
# 14 font faire
# 17 la le
# 20 leur son
# 21 produits produit
# 24 vont aller
# 27 de un
# 31 indienne indien
# 34 produits produit
# 37 contiennent contenir
# 40 l' le
#
# 9 Je rappelle que les produits vegans sont majoritairement des légumes et des fruits indispensable à notre santé à tous.
# 1 Je moi
# 2 rappelle rappeler
# 4 les le
# 5 produits produit
# 6 vegans vegan
# 7 sont être
# 9 des un
# 10 légumes légume
# 12 des un
# 13 fruits fruit
# 16 notre son
# 19 tous tout
#
# 10 Donc vous en consommez.
# 1 Donc donc
# 4 consommez consommer
#
# 11 Pour la viande, elle n'est pas indispensable à notre organisme (aujourd'hui et dans notre société mondialisée où l'on peut trouver plein d'autres produits tel que les légumineuses qui contiennent fer et protéines...) Cuire les aliments nous a permis en effet de faire évoluer notre cerveau car l'on pouvait digérer plus vite.
# 1 Pour pour
# 2 la le
# 5 elle lui
# 6 n' ne
# 7 est être
# 11 notre son
# 17 notre son
# 19 mondialisée mondialisé
# 21 l'on on
# 22 peut pouvoir
# 25 d' de
# 26 autres autre
# 27 produits produit
# 30 les le
# 31 légumineuses légumineuse
# 33 contiennent contenir
# 36 protéines protéine
# 39 Cuire cuire
# 40 les le
# 41 aliments aliment
# 43 a avoir
# 44 permis permettre
# 50 notre son
# 53 l'on on
# 54 pouvait pouvoir
#
# 12 Je dis bien aliments et pas simplement la viande comme l'a dit un autre commentaire.
# 1 Je moi
# 2 dis dire
# 4 aliments aliment
# 8 la le
# 11 l' lui
# 12 a avoir
# 13 dit dire
#
# 13 D'autant que les végétaux se digèrent plus vite...
# 1 D' de
# 4 les le
# 5 végétaux végétal
# 6 se soi
# 7 digèrent digérer
#
# 14 De plus a l'époque paléolithique, on mangeait très peu de viande contrairement aux idées reçues...
# 1 De de
# 3 a à
# 4 l' le
# 9 mangeait manger
# 16 les le
# 17 idées idée
# 18 reçues recevoir
#
# 15 On chassait avec des lances, c'était dur, y avait des morts a chaque chasse.
# 1 On on
# 2 chassait chasser
# 4 des un
# 5 lances lance
# 7 c' ce
# 8 était être
# 12 avait avoir
# 13 des un
# 14 morts mort
# 15 a à
#
# 16 Donc bon... Mangez de la viande si vous voulez, mais quel intérêt de critiquer ceux qu'en ...
# 1 Donc donc
# 4 Mangez manger
# 6 la le
# 10 voulez vouloir
# 17 ceux celui
# 18 qu' que
#
# 17 Également, POURQUOI puisqu'ils refusent tous produits carnés ou d'origine animale, VEULENT ils en fabriquer qui ressembles aux produit d'origine animale ??? steak haché (de soja), fromage ( huile de cajou), lait (de soja ou autre), etc etc... pourquoi ce mimétisme alimentaire ?
# 1 Également également
# 3 POURQUOI pourquoi
# 4 puisqu' puisque
# 5 ils eux
# 6 refusent refuser
# 7 tous tout
# 8 produits produit
# 9 carnés carner
# 11 d' de
# 13 animale animal
# 15 VEULENT veuloir
# 16 ils eux
# 20 ressembles ressembler
# 22 les le
# 24 d' de
# 26 animale animal
# 29 haché hacher
#
# 18 sont ils en manque de nos produits ?
# 1 sont être
# 2 ils eux
# 4 manque manquer
# 6 nos son
# 7 produits produit
#
# 19 ne peuvent ils manger QUE si ça ressemble à nos produits afin de tromper le cerveau ?
# 2 peuvent pouvoir
# 3 ils eux
# 5 QUE que
# 8 ressemble ressembler
# 10 nos son
# 11 produits produit

# %% [markdown]
# ## 2. Testing Lemmatization

# %% [markdown]
# In the example, we see that in sentence 19, the lemma for "VEULENT" is "vevler". The correct lemma should be "vouloir".
#
# A reason for this mistake might be that the word is written in all-caps. Let's check this:

# %%
# Let's write a function for testing a single sentence. 
def get_lemmas(input, stanza_pipeline): 
    # This is a quite complex list comprehension. Make sure you understand what it does. 
    lemmas = [word.lemma for word in stanza_pipeline(input).sentences[0].words]
    return lemmas

# We use a faster pipeline that does not perform all processing steps, only tokenization, POS-tagging and lemmatization
french_pipeline = stanza.Pipeline('fr', processors='tokenize,pos,lemma')
test1 = 'Ils veulent fabriquer quelque chose.'
test2 = 'Ils VEULENT fabriquer quelque chose.'

print(get_lemmas(test1, french_pipeline))
print(get_lemmas(test2, french_pipeline))
# Out:
# 2023-10-18 11:37:06 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2023-10-18 11:37:06 WARNING: Language fr package default expects mwt, which has been added
# 2023-10-18 11:37:06 INFO: Loading these models for language: fr (French):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# =================================
#
# 2023-10-18 11:37:06 INFO: Using device: cpu
# 2023-10-18 11:37:06 INFO: Loading: tokenize
# 2023-10-18 11:37:07 INFO: Loading: mwt
# 2023-10-18 11:37:07 INFO: Loading: pos
# 2023-10-18 11:37:07 INFO: Loading: lemma
# 2023-10-18 11:37:07 INFO: Done loading processors!
# ['eux', 'vouloir', 'fabriquer', 'quelque', 'chose', '.']
# ['eux', 'veuloir', 'fabriquer', 'quelque', 'chose', '.']

# %% [markdown]
# **Test the lemmatization quality for your own datasets. Collect the tricky cases in this [document](https://docs.google.com/document/d/1tU7KD-WrwYAieMH_Q-6z69NFleTJwp8zIUpCr_rbwlA/edit?usp=sharing)**
#
# Sometimes the problem lies already in the tokenization. Do you also find cases for incorrect tokenization?
#
# If you find many inconsistencies, you can compare the quality to the output of the nltk or spacy lemmatizer.

# %% [markdown]
# ## 3. Adding exceptions

# %% [markdown]
# The stanza lemmatizer uses a combination of a dictionary and a neural model. The lemma for any word that cannot be found in the dictionary is approximated by the neural model. Combining several resources is called an ensemble model.
#
# We can customize the dictionary to add our own solutions. Check the [documentation](https://stanfordnlp.github.io/stanza/lemma.html#accessing-lemma-for-word).
#
# **Important: If you modify the pipeline like this, you need to be very transparent in your documentation and provide the modified model (or the code to obtain it) to ensure reproducibility!**

# %%
import torch
from os.path import expanduser

# Load the current dictionaries
home = expanduser("~")
# if this is not working, double-check which dictionary is used by your version of stanza
model = torch.load(home +'/stanza_resources/fr/lemma/gsd.pt', map_location='cpu')
word_dict = model['dicts'][0]

# Add a word to the dictionary
word_dict['VEULENT'] = 'vouloir'

# Save the modified model under a different name
torch.save(model, home + '/stanza_resources/fr/lemma/gsd_customized.pt')

# Load your customized pipeline
customized_pipeline = stanza.Pipeline('fr', package='gsd', processors='tokenize,pos,lemma', lemma_model_path=home + '/stanza_resources/fr/lemma/gsd_customized.pt')
test = 'Ils VEULENT fabriquer quelque chose.'
print(get_lemmas(test, customized_pipeline))
# Out:
# 2023-10-18 11:38:19 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2023-10-18 11:38:19 WARNING: Language fr package gsd expects mwt, which has been added
# 2023-10-18 11:38:20 INFO: Loading these models for language: fr (French):
# =======================================
# | Processor | Package                 |
# ---------------------------------------
# | tokenize  | gsd                     |
# | mwt       | gsd                     |
# | pos       | gsd_charlm              |
# | lemma     | /Users/lis...tomized.pt |
# =======================================
#
# 2023-10-18 11:38:20 INFO: Using device: cpu
# 2023-10-18 11:38:20 INFO: Loading: tokenize
# 2023-10-18 11:38:20 INFO: Loading: mwt
# 2023-10-18 11:38:20 INFO: Loading: pos
# 2023-10-18 11:38:20 INFO: Loading: lemma
# 2023-10-18 11:38:20 INFO: Done loading processors!
# ['il', 'vouloir', 'fabriquer', 'quelque', 'chose', '.']

# %% [markdown]
# ## 3. POS-tags

# %% [markdown]
# The same lemma can occur in different word classes. For example, *run* can be a verb or a noun. When calculating word frequencies, you might want to distinguish between different POS-tags.

# %%
from collections import Counter

token_pos_frequencies = Counter()
for sentence in nlp_output.sentences:
    # Here you could also use word.text instead of word.lemma. Test if it makes a difference!
    token_pos = [(word.lemma, word.pos) for word in sentence.words]
    token_pos_frequencies.update(token_pos)
    
print(token_pos_frequencies.most_common(50))
# Out:
# [(('le', 'DET'), 55), (('de', 'ADP'), 49), ((',', 'PUNCT'), 31), (('un', 'DET'), 20), (('.', 'PUNCT'), 18), (('à', 'ADP'), 16), (('être', 'AUX'), 16), (('son', 'DET'), 15), (('et', 'CCONJ'), 14), (('...', 'PUNCT'), 13), (('?', 'PUNCT'), 12), (('pas', 'ADV'), 10), (('produit', 'NOUN'), 10), (('ne', 'ADV'), 10), (('pour', 'ADP'), 10), (('en', 'PRON'), 9), (('eux', 'PRON'), 8), (('vous', 'PRON'), 7), (('vouloir', 'VERB'), 7), (('lui', 'PRON'), 6), (('qui', 'PRON'), 6), (('on', 'PRON'), 6), (('plus', 'ADV'), 5), (('lait', 'NOUN'), 5), (('cajou', 'NOUN'), 5), (('alors', 'ADV'), 5), (('manger', 'VERB'), 5), (('ça', 'PRON'), 5), (('ce', 'PRON'), 5), (('ou', 'CCONJ'), 5), (('moi', 'PRON'), 5), (('viande', 'NOUN'), 5), (('pouvoir', 'VERB'), 5), (('nous', 'PRON'), 5), (('avoir', 'AUX'), 5), (('si', 'SCONJ'), 5), (('mais', 'CCONJ'), 5), (('en', 'ADP'), 4), (('"', 'PUNCT'), 4), (('noix', 'NOUN'), 4), (('y', 'PRON'), 4), (('soja', 'NOUN'), 4), (('vegan', 'NOUN'), 4), (('que', 'SCONJ'), 4), (('(', 'PUNCT'), 4), ((')', 'PUNCT'), 4), (('encore', 'ADV'), 4), (('avoir', 'VERB'), 3), (('vegan', 'ADJ'), 3), (('dire', 'VERB'), 3)]

# %% [markdown]
# ## 4. Stopwords

# %% [markdown]
# The most frequent words are stopwords. For some research questions, it might make sense to ignore the stopwords.
#
# **Search for the commonly used stopwords for your target language. Discuss the role of stopwords for your dataset. **
#
# Do you see a difference in the most frequent tokens if you ignore stopwords?

# %%
import string
# These are the stopwords defined for French in the nltk module and I added the determiners "d'" and "l'"
stopwords = ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', "d'",'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les',"l'", 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'aurez', 'auront', 'aurais', 'aurait', 'aurions', 'auriez', 'auraient', 'avais', 'avait', 'avions', 'aviez', 'avaient', 'eut', 'eûmes', 'eûtes', 'eurent', 'aie', 'aies', 'ait', 'ayons', 'ayez', 'aient', 'eusse', 'eusses', 'eût', 'eussions', 'eussiez', 'eussent']

def calculate_token_frequencies(nlp_output, ignore_stopwords=False):
    token_frequencies = Counter()
    for sentence in nlp_output.sentences:
        if ignore_stopwords:
        # Take some time to understand the syntax of the list comprehension, for ignoring stopwords.
        # It is not intuitive
            tokens = [token.text for token in sentence.tokens if token.text not in stopwords ]
        else:
            tokens = [token.text for token in sentence.tokens]

        token_frequencies.update(tokens)
    return token_frequencies

token_frequencies = calculate_token_frequencies(nlp_output, ignore_stopwords=False)
print(token_frequencies.most_common(20))
# Out:
#   Cell In[9], line 11
#     tokens = [token.text for token in sentence.tokens if token.text not in stopwords ]
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ## 5. Normalization

# %% [markdown]
# If we want to determine the relative importance of a term for an article, we can normalize its frequency by the frequency of the term in all articles.
#
# The code currently distinguishes between uppercase and lowercase words. For many languages and tasks, it is useful to lowercase all words. **Think about the influence of casing on your research question.**

# %%
frequencies_currentarticle = calculate_token_frequencies(nlp_output)

# You calculated the document frequencies in the previous lab
frequencies_dataset = pickle.load(open("../data/processed_data/tokenfrequencies.pkl","rb"))

normalized_frequencies = Counter()
for token, freq in frequencies_currentarticle.items():
    # Remove stopwords and punctuation? --> experimental choice
    if not token in stopwords and not token in string.punctuation:
        normalized_frequency = float(freq/frequencies_dataset[token])
        normalized_frequencies[token] = normalized_frequency
    
print(normalized_frequencies.most_common(100))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 9
#       6 for term, freq in frequencies_currentarticle.items():
#       7     # Remove stopwords and punctuation? --> experimental choice
#       8     if not term in stopwords and not term in string.punctuation:
# ----> 9         normalized_frequency = float(freq/frequencies_dataset[term])
#      10         normalized_frequencies[term] = normalized_frequency
#      12 print(normalized_frequencies.most_common(100))
#
# ZeroDivisionError: division by zero

# %% [markdown]
# The code currently throws a *ZeroDivisionError*. **What does that mean and how can you fix it?**
