# %% [markdown]
# ## Lab 1.5: Scraping Mastodon

# %% [markdown]
# In this notebook we will be scraping messages from [Mastodon](https://docs.joinmastodon.org/), an open-source alternative to Twitter (X). The messages send over Mastodon are called *toots*. **Check the code to crawl toots below and try to understand the structure of the toots in JSON format.**

# %% [markdown]
# ## 1. Crawling Toots

# %%
import json
import requests
import pandas as pd
import pprint

# Set up your keyword(s) for the hashtag
hashtag = 'veganism'  
URL = f'https://mastodon.social/api/v1/timelines/tag/{hashtag}'

# You can crawl at most 40 toots at once
params = {'limit': 40}

response = requests.get(URL, params=params)
toots = json.loads(response.text)  # saves to json object
   
# We use prettyprint to add indents to the output
pp = pprint.PrettyPrinter(indent=1)
for toot in toots[0:2]:
    pp.pprint(toot)
    print("\n---------------\n")
# Out:
# {'account': {'acct': 'Dragofix@veganism.social',
#              'avatar': 'https://files.mastodon.social/cache/accounts/avatars/110/655/611/816/281/403/original/7308e356acdc0d15.png',
#              'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/110/655/611/816/281/403/original/7308e356acdc0d15.png',
#              'bot': False,
#              'created_at': '2023-07-04T00:00:00.000Z',
#              'discoverable': True,
#              'display_name': 'Dragofix',
#              'emojis': [],
#              'fields': [],
#              'followers_count': 139,
#              'following_count': 195,
#              'group': False,
#              'header': 'https://files.mastodon.social/cache/accounts/headers/110/655/611/816/281/403/original/c2cf1019fc1ae307.gif',
#              'header_static': 'https://files.mastodon.social/cache/accounts/headers/110/655/611/816/281/403/static/c2cf1019fc1ae307.png',
#              'id': '110655611816281403',
#              'last_status_at': '2023-10-17',
#              'locked': False,
#              'note': '<p>Minimalism, health, organic healthy plant-based food, '
#                      'nature, environment, biodiversity, animal &amp; human '
#                      'rights Ⓥ etc. In Finnish at <span class="h-card" '
#                      'translate="no"><a '
#                      'href="https://mastodontti.fi/@Dragofix" class="u-url '
#                      'mention" rel="nofollow noopener noreferrer" '
#                      'target="_blank">@<span>Dragofix</span></a></span></p>',
#              'statuses_count': 2853,
#              'uri': 'https://veganism.social/users/Dragofix',
#              'url': 'https://veganism.social/@Dragofix',
#              'username': 'Dragofix'},
#  'card': {'author_name': '',
#           'author_url': '',
#           'blurhash': 'UIHK;C~V74E18^?Hi]NdFzZ~#kaf-nkrOaNa',
#           'description': 'Sustainability platform abillion has published a '
#                          "list of the world's top 50 vegan restaurants based "
#                          'on member reviews of over 265,000 dishes across 70',
#           'embed_url': '',
#           'height': 1200,
#           'html': '',
#           'image': 'https://files.mastodon.social/cache/preview_cards/images/076/286/238/original/bfd5b82e48fa9905.jpg',
#           'image_description': 'vegan restaurants',
#           'language': 'en',
#           'provider_name': 'vegconomist - the vegan business magazine',
#           'provider_url': '',
#           'published_at': '2023-10-16T11:53:21.000Z',
#           'title': 'abillion Ranks the Top 50 Vegan Restaurants Worldwide - '
#                    'vegconomist - the vegan business magazine',
#           'type': 'link',
#           'url': 'https://vegconomist.com/gastronomy-food-service/food-service/abillion-top-50-vegan-restaurants/',
#           'width': 1200},
#  'content': '<p>abillion Ranks the Top 50 Vegan Restaurants Worldwide <a '
#             'href="https://veganism.social/tags/vegan" class="mention hashtag" '
#             'rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>vegan</span></a> <a '
#             'href="https://veganism.social/tags/restaurant" class="mention '
#             'hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>restaurant</span></a> <a '
#             'href="https://veganism.social/tags/restaurants" class="mention '
#             'hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>restaurants</span></a> <a '
#             'href="https://veganism.social/tags/plantbased" class="mention '
#             'hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>plantbased</span></a> <a '
#             'href="https://veganism.social/tags/food" class="mention hashtag" '
#             'rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>food</span></a> <a '
#             'href="https://veganism.social/tags/veganism" class="mention '
#             'hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>veganism</span></a> <a '
#             'href="https://veganism.social/tags/GoVegan" class="mention '
#             'hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>GoVegan</span></a> <a '
#             'href="https://vegconomist.com/gastronomy-food-service/food-service/abillion-top-50-vegan-restaurants/" '
#             'rel="nofollow noopener noreferrer" translate="no" '
#             'target="_blank"><span class="invisible">https://</span><span '
#             'class="ellipsis">vegconomist.com/gastronomy-foo</span><span '
#             'class="invisible">d-service/food-service/abillion-top-50-vegan-restaurants/</span></a></p>',
#  'created_at': '2023-10-17T20:52:31.000Z',
#  'edited_at': None,
#  'emojis': [],
#  'favourites_count': 0,
#  'id': '111252337696188724',
#  'in_reply_to_account_id': None,
#  'in_reply_to_id': None,
#  'language': 'en',
#  'media_attachments': [],
#  'mentions': [],
#  'poll': None,
#  'reblog': None,
#  'reblogs_count': 2,
#  'replies_count': 0,
#  'sensitive': False,
#  'spoiler_text': '',
#  'tags': [{'name': 'vegan', 'url': 'https://mastodon.social/tags/vegan'},
#           {'name': 'restaurant',
#            'url': 'https://mastodon.social/tags/restaurant'},
#           {'name': 'restaurants',
#            'url': 'https://mastodon.social/tags/restaurants'},
#           {'name': 'plantbased',
#            'url': 'https://mastodon.social/tags/plantbased'},
#           {'name': 'food', 'url': 'https://mastodon.social/tags/food'},
#           {'name': 'veganism', 'url': 'https://mastodon.social/tags/veganism'},
#           {'name': 'govegan', 'url': 'https://mastodon.social/tags/govegan'}],
#  'uri': 'https://veganism.social/users/Dragofix/statuses/111252337556716214',
#  'url': 'https://veganism.social/@Dragofix/111252337556716214',
#  'visibility': 'public'}
#
# ---------------
#
# {'account': {'acct': 'joe8Zeta7',
#              'avatar': 'https://files.mastodon.social/accounts/avatars/110/332/901/390/156/370/original/b06448d84952c0f9.png',
#              'avatar_static': 'https://files.mastodon.social/accounts/avatars/110/332/901/390/156/370/original/b06448d84952c0f9.png',
#              'bot': False,
#              'created_at': '2023-05-08T00:00:00.000Z',
#              'discoverable': False,
#              'display_name': 'Giuseppe Zolli',
#              'emojis': [],
#              'fields': [],
#              'followers_count': 186,
#              'following_count': 168,
#              'group': False,
#              'header': 'https://files.mastodon.social/accounts/headers/110/332/901/390/156/370/original/829040a5d1c4cd01.jpg',
#              'header_static': 'https://files.mastodon.social/accounts/headers/110/332/901/390/156/370/original/829040a5d1c4cd01.jpg',
#              'id': '110332901390156370',
#              'last_status_at': '2023-10-17',
#              'locked': False,
#              'noindex': False,
#              'note': '<p>MD in IT Engineering | Freelance | Environmental '
#                      'activist 🌍 | Ebook creator &amp; advisor | Tester | '
#                      'Italian 🇮🇹 | <a '
#                      'href="https://mastodon.social/tags/ConnectAID" '
#                      'class="mention hashtag" '
#                      'rel="tag">#<span>ConnectAID</span></a> team member | <a '
#                      'href="https://mastodon.social/tags/SDGs" class="mention '
#                      'hashtag" rel="tag">#<span>SDGs</span></a></p>',
#              'roles': [],
#              'statuses_count': 944,
#              'uri': 'https://mastodon.social/users/joe8Zeta7',
#              'url': 'https://mastodon.social/@joe8Zeta7',
#              'username': 'joe8Zeta7'},
#  'application': {'name': 'Web', 'website': None},
#  'card': {'author_name': '',
#           'author_url': '',
#           'blurhash': 'UMD^J}EK6,%4?bb_M_f61##7$hOsIpj]tRiw',
#           'description': "L'Italia ha ritirato il ddl che prevede il divieto "
#                          'di produzione e vendita della carne coltivata, oltre '
#                          'che la censura dei prodotti vegetali.',
#           'embed_url': '',
#           'height': 754,
#           'html': '',
#           'image': 'https://files.mastodon.social/cache/preview_cards/images/076/137/581/original/9e9eef508dd65049.png',
#           'image_description': '',
#           'language': 'it',
#           'provider_name': 'Essere Animali',
#           'provider_url': '',
#           'published_at': '2023-10-16T12:35:34.000Z',
#           'title': 'Dietrofront del Governo sulla legge che vieta la carne '
#                    'coltivata e censura i prodotti veg',
#           'type': 'link',
#           'url': 'https://www.essereanimali.org/2023/10/governo-dietrofront-legge-carne-coltivata-censura-veg/',
#           'width': 1440},
#  'content': '<p>Dietrofront del Governo sulla legge che vieta la carne '
#             'coltivata e censura i prodotti vegetali<br /><a '
#             'href="https://mastodon.social/tags/AnimalCruelty" class="mention '
#             'hashtag" rel="tag">#<span>AnimalCruelty</span></a> <a '
#             'href="https://mastodon.social/tags/StopAnimalAbuse" '
#             'class="mention hashtag" '
#             'rel="tag">#<span>StopAnimalAbuse</span></a> <a '
#             'href="https://mastodon.social/tags/StopAnimalCruelty" '
#             'class="mention hashtag" '
#             'rel="tag">#<span>StopAnimalCruelty</span></a> <a '
#             'href="https://mastodon.social/tags/animals" class="mention '
#             'hashtag" rel="tag">#<span>animals</span></a> <a '
#             'href="https://mastodon.social/tags/animal" class="mention '
#             'hashtag" rel="tag">#<span>animal</span></a> <a '
#             'href="https://mastodon.social/tags/AnimalRights" class="mention '
#             'hashtag" rel="tag">#<span>AnimalRights</span></a> <a '
#             'href="https://mastodon.social/tags/veganfood" class="mention '
#             'hashtag" rel="tag">#<span>veganfood</span></a> <a '
#             'href="https://mastodon.social/tags/veganism" class="mention '
#             'hashtag" rel="tag">#<span>veganism</span></a> <a '
#             'href="https://mastodon.social/tags/GoVegan" class="mention '
#             'hashtag" rel="tag">#<span>GoVegan</span></a> <br /><a '
#             'href="https://www.essereanimali.org/2023/10/governo-dietrofront-legge-carne-coltivata-censura-veg/" '
#             'target="_blank" rel="nofollow noopener noreferrer" '
#             'translate="no"><span class="invisible">https://www.</span><span '
#             'class="ellipsis">essereanimali.org/2023/10/gove</span><span '
#             'class="invisible">rno-dietrofront-legge-carne-coltivata-censura-veg/</span></a></p>',
#  'created_at': '2023-10-16T13:41:59.163Z',
#  'edited_at': None,
#  'emojis': [],
#  'favourites_count': 0,
#  'id': '111244982296730844',
#  'in_reply_to_account_id': None,
#  'in_reply_to_id': None,
#  'language': 'it',
#  'media_attachments': [],
#  'mentions': [],
#  'poll': None,
#  'reblog': None,
#  'reblogs_count': 0,
#  'replies_count': 0,
#  'sensitive': False,
#  'spoiler_text': '',
#  'tags': [{'name': 'animalcruelty',
#            'url': 'https://mastodon.social/tags/animalcruelty'},
#           {'name': 'stopanimalabuse',
#            'url': 'https://mastodon.social/tags/stopanimalabuse'},
#           {'name': 'stopanimalcruelty',
#            'url': 'https://mastodon.social/tags/stopanimalcruelty'},
#           {'name': 'animals', 'url': 'https://mastodon.social/tags/animals'},
#           {'name': 'animal', 'url': 'https://mastodon.social/tags/animal'},
#           {'name': 'animalrights',
#            'url': 'https://mastodon.social/tags/animalrights'},
#           {'name': 'veganfood',
#            'url': 'https://mastodon.social/tags/veganfood'},
#           {'name': 'veganism', 'url': 'https://mastodon.social/tags/veganism'},
#           {'name': 'govegan', 'url': 'https://mastodon.social/tags/govegan'}],
#  'uri': 'https://mastodon.social/users/joe8Zeta7/statuses/111244982296730844',
#  'url': 'https://mastodon.social/@joe8Zeta7/111244982296730844',
#  'visibility': 'public'}
#
# ---------------

# %% [markdown]
# ## 2. Inspecting metadata

# %% [markdown]
# The toots come with a complex metadata structure. JSON represents this as nested dictionaries and you can access information using the respective keys. **Inspect the metadata structure and reflect how the information is relevant for your analysis.**
#
# If you use keys such as *language*, *sensitive*, or *bot* for filtering the posts, you should **check in the documentation how this information is determined.** It might be the case that some information is missing, i.e., some keys are not necessarily available for all toots.

# %%
import html2text
print("Metadata for toot:")
print(posts[0].keys())
print()

# The json format is a nested dictionary
print("Metadata for user account which posted toot:")
print(posts[0]["account"].keys())
print()
      
print(html2text.html2text(posts[2]["content"]))
# Out:
# Metadata for toot:
# dict_keys(['id', 'created_at', 'in_reply_to_id', 'in_reply_to_account_id', 'sensitive', 'spoiler_text', 'visibility', 'language', 'uri', 'url', 'replies_count', 'reblogs_count', 'favourites_count', 'edited_at', 'content', 'reblog', 'account', 'media_attachments', 'mentions', 'tags', 'emojis', 'card', 'poll'])
#
# Metadata for user account which posted toot:
# dict_keys(['id', 'username', 'acct', 'display_name', 'locked', 'bot', 'discoverable', 'group', 'created_at', 'note', 'url', 'uri', 'avatar', 'avatar_static', 'header', 'header_static', 'followers_count', 'following_count', 'statuses_count', 'last_status_at', 'emojis', 'fields'])
#
# Someone posted this months ago. Took me ages to find it again.
#
# “Veganism is a stance against injustice”
#
# \- really hit home
#
# [https://www.speciesrevolution.org/language/](https://www.speciesrevolution.org/language/)
#
# [#Veganism](https://veganism.social/tags/Veganism)

# %% [markdown]
# ## 3. Getting around the limit
#
# For every request, you can only access at most 40 toots. To get around this, we need to look at the unique identifier (id) of the toot. Toots that have been created later, have a larger id.

# %%
num_toots = 200
results = []

# Be careful, if this expression never evaluates to False, 
# you will be stuck in an endless loop

while len(results) < num_toots:
    
    # Send query
    r = requests.get(URL, params=params)
    toots = json.loads(r.text)  # saves to json object
    
    # If we do not get any results, we leave the loop (although we might have collected less than num_toots)
    if len(toots) == 0: 
        break
    
    for toot in toots: 
        results.append(toot)
        if len(results) == num_toots:
            break
            
        
    max_id = toots[-1]['id'] 
    # We add the parameter max_id to our request
    params['max_id'] = max_id
    
    print("Next request looking at toots with ids smaller than: ")
    print(max_id)
    
    
print(results[199:200])
# Out:
# Next request looking at toots with ids smaller than:
# 111184512588629029
# Next request looking at toots with ids smaller than:
# 111144822869468287
# Next request looking at toots with ids smaller than:
# 111059287962426939
# Next request looking at toots with ids smaller than:
# 111024900088312612
# Next request looking at toots with ids smaller than:
# 110945223679337306
# [{'id': '110945223679337306', 'created_at': '2023-08-24T15:09:12.000Z', 'in_reply_to_id': None, 'in_reply_to_account_id': None, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://social.coop/users/lukemartell/statuses/110945222808534663', 'url': 'https://social.coop/@lukemartell/110945222808534663', 'replies_count': 0, 'reblogs_count': 5, 'favourites_count': 1, 'edited_at': None, 'content': '<p>\'Hens\' suffering at megafarm exposed\'. Absolutely appalling.<br><a href="https://theecologist.org/2023/aug/24/hens-suffering-megafarm-exposed" rel="nofollow noopener noreferrer" target="_blank"><span class="invisible">https://</span><span class="ellipsis">theecologist.org/2023/aug/24/h</span><span class="invisible">ens-suffering-megafarm-exposed</span></a><br><a href="https://social.coop/tags/animalcruelty" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>animalcruelty</span></a> <a href="https://social.coop/tags/animalrights" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>animalrights</span></a> <a href="https://social.coop/tags/veganism" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>veganism</span></a></p>', 'reblog': None, 'account': {'id': '109295776384464680', 'username': 'lukemartell', 'acct': 'lukemartell@social.coop', 'display_name': 'Luke Martell', 'locked': False, 'bot': False, 'discoverable': True, 'group': False, 'created_at': '2022-11-06T00:00:00.000Z', 'note': '<p>Political sociology tutor interested in socialism, social democracy, social and ecological alternatives, and global politics.</p>', 'url': 'https://social.coop/@lukemartell', 'uri': 'https://social.coop/users/lukemartell', 'avatar': 'https://files.mastodon.social/cache/accounts/avatars/109/295/776/384/464/680/original/907e02cf2437ce53.jpeg', 'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/109/295/776/384/464/680/original/907e02cf2437ce53.jpeg', 'header': 'https://files.mastodon.social/cache/accounts/headers/109/295/776/384/464/680/original/1db2535d43f33a02.jpg', 'header_static': 'https://files.mastodon.social/cache/accounts/headers/109/295/776/384/464/680/original/1db2535d43f33a02.jpg', 'followers_count': 719, 'following_count': 202, 'statuses_count': 467, 'last_status_at': '2023-10-16', 'emojis': [], 'fields': [{'name': 'Web page', 'value': '<a href="https://profiles.sussex.ac.uk/p1720-luke-martell" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">profiles.sussex.ac.uk/p1720-lu</span><span class="invisible">ke-martell</span></a>', 'verified_at': None}, {'name': 'Alternative Societies', 'value': '<a href="https://bristoluniversitypress.co.uk/alternative-societies" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">bristoluniversitypress.co.uk/a</span><span class="invisible">lternative-societies</span></a>', 'verified_at': None}]}, 'media_attachments': [], 'mentions': [], 'tags': [{'name': 'animalcruelty', 'url': 'https://mastodon.social/tags/animalcruelty'}, {'name': 'animalrights', 'url': 'https://mastodon.social/tags/animalrights'}, {'name': 'veganism', 'url': 'https://mastodon.social/tags/veganism'}], 'emojis': [], 'card': {'url': 'https://theecologist.org/2023/aug/24/hens-suffering-megafarm-exposed', 'title': "Hens' suffering at megafarm exposed", 'description': 'Tories fail to ban hen cages as new investigation reveals cruelty at farm supplying eggs to Lidl supermarket.', 'language': 'en', 'type': 'link', 'author_name': '', 'author_url': '', 'provider_name': 'The Ecologist', 'provider_url': '', 'html': '', 'width': 1200, 'height': 630, 'image': 'https://files.mastodon.social/cache/preview_cards/images/070/986/531/original/1f22a32952a54c22.jpg', 'image_description': '', 'embed_url': '', 'blurhash': 'UFATTORQ4.tQ9F%LxuRk0KIo?Gsm?bRjI ...

# %% [markdown]
# You can additionally use the "created_at" timestamp to limit your toots to a certain time period.

# %% [markdown]
# ## Reproducibility
#
# If someone else crawls toots using your code at a later time, they will retrieve a different set because Mastodon always returns the most recent toots first.
#
# To avoid this, you should provide a list of ids of your crawled toots.

# %%
ids = [toot["id"] for toot in results]
# You can specifiy the id of the toot you want to crawl
params = {'id': ids[0]}

r = requests.get(URL, params=params)
toots = json.loads(r.text)  # saves to json object

print(toots[0]["content"] == results[0]["content"])
# Out:
# True

# %% [markdown]
# **How do you need to adjust the above code to write a function that yields the correct toots when given a list of ids?** Keep in mind that toots might have been deleted by a user in the meantime. In that case, it is impossible to retrieve the same set of toots. You need to make sure that the code deals with this exception and outputs an appropriate warning.

# %% [markdown]
# ## 4. Saving results
#
# We have two options for saving the results.
# 1. We can select specific attributes and save them as a tsv-file.
# 2. If we do not want to decide yet which attributes we need, we can simply dump the whole JSON result to a file and process it later.
#
# **Make sure that you understand the code below. Open the result files in an editor and compare the differences.**

# %%
# Collect the results
toots_as_json =[]
toots_as_text =[]

for toot in toots: 
    # TODO: You might want to apply some filtering based on metadata here
    
    # Option 1: only keep selected attributes
    text= html2text.html2text(toot["content"])
    keep = str(toot["created_at"]) + "\t" + str(toot["id"]) + str(toot["account"]["id"]) + "\t" + text
    toots_as_text.append(keep)  
    
    # Option 2: keep everything and process later
    toots_as_json.append(toot)
    
# Write them to a file
csv_file = "../results/mastodon_search_results/results_veganism.csv"
json_file = "../results/mastodon_search_results/results_veganism.json"

with open(csv_file, 'w',encoding="utf-8") as outfile:
    csv_header = "Created at\tUser\tText\n"
    outfile.write(csv_header)
    outfile.write("\n".join(toots_as_text))

with open(json_file, 'w') as outfile:
    json.dump(toots_as_json, outfile)
