# %% [markdown]
# ## Lab 1.5: Scraping Mastodon

# %% [markdown]
# In this notebook we will be scraping messages from [Mastodon](https://docs.joinmastodon.org/), an open-source alternative to Twitter (X). The messages send over Mastodon are called *toots*. **Check the code to crawl toots below and try to understand the structure of the toots in JSON format.**

# %% [markdown]
# ## 1. Crawling Toots

# %%
import json
import requests
import pandas as pd
import pprint

# Set up your keyword(s) for the hashtag
hashtag = 'veganism'  
URL = f'https://mastodon.social/api/v1/timelines/tag/{hashtag}'

# You can crawl at most 40 toots at once
params = {'limit': 40}

response = requests.get(URL, params=params)
toots = json.loads(response.text)  # saves to json object
   
# We use prettyprint to add indents to the output
pp = pprint.PrettyPrinter(indent=1)
for toot in toots[0:2]:
    pp.pprint(toot)
    print("\n---------------\n")
# Out:
# {'account': {'acct': 'SofiaK@social.politicaconciencia.org',
#              'avatar': 'https://files.mastodon.social/cache/accounts/avatars/106/604/592/089/366/171/original/f3f8499cf48abaa5.gif',
#              'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/106/604/592/089/366/171/static/f3f8499cf48abaa5.png',
#              'bot': False,
#              'created_at': '2021-07-18T00:00:00.000Z',
#              'discoverable': False,
#              'display_name': '¡Emancipemos a los animales!',
#              'emojis': [],
#              'fields': [],
#              'followers_count': 351,
#              'following_count': 526,
#              'group': False,
#              'header': 'https://files.mastodon.social/cache/accounts/headers/106/604/592/089/366/171/original/aacb7722bcf3d8ca.gif',
#              'header_static': 'https://files.mastodon.social/cache/accounts/headers/106/604/592/089/366/171/static/aacb7722bcf3d8ca.png',
#              'id': '106604592089366171',
#              'last_status_at': '2023-11-02',
#              'locked': True,
#              'note': '<p>Terrícola; estoy en esta red social porque busco '
#                      'libertad y para difundir una de mis misiones: fin a la '
#                      'esclavitud de todos los animales.</p><p>¡Libertad a los '
#                      'animales no humanos!, y a los animales humanos, por '
#                      'supuesto.</p><p>Por favor, antes de pedirme seguimiento, '
#                      'habla conmigo.</p>',
#              'statuses_count': 7398,
#              'uri': 'https://social.politicaconciencia.org/users/SofiaK',
#              'url': 'https://social.politicaconciencia.org/@SofiaK',
#              'username': 'SofiaK'},
#  'card': None,
#  'content': '<p>Hoy las veganas llamamos a que se consuma el primer derecho y '
#             'el más importantes de las demás animales: la <a '
#             'href="https://social.politicaconciencia.org/tags/libertad" '
#             'class="mention hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>libertad</span></a>, que no sean esclavas, '
#             'que no se les explote, que vivan bajo sus propios términos. '
#             '</p><p>El objetivo del veganismo es emancipar a las demás '
#             'animales.</p><p>El sujeto político del veganismo son las demás '
#             'animales sintientes (casi todos).</p><p>¿Por qué digo "las"? '
#             '<br>Porque son las personas no humanas.</p><p>¿Por qué la '
#             'libertad es el más importante derecho ético? Porque sin ella '
#             'pueden hacer con nosotros lo que quieran los amos.</p><p>1 de '
#             'noviembre día del <a '
#             'href="https://social.politicaconciencia.org/tags/veganismo" '
#             'class="mention hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>veganismo</span></a>.</p><p><a '
#             'href="https://social.politicaconciencia.org/tags/GoVegan" '
#             'class="mention hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>GoVegan</span></a> <br><a '
#             'href="https://social.politicaconciencia.org/tags/veganism" '
#             'class="mention hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>veganism</span></a></p>',
#  'created_at': '2023-11-02T03:59:51.000Z',
#  'edited_at': '2023-11-02T05:14:26.000Z',
#  'emojis': [],
#  'favourites_count': 0,
#  'id': '111338953022051403',
#  'in_reply_to_account_id': None,
#  'in_reply_to_id': None,
#  'language': 'es',
#  'media_attachments': [{'blurhash': 'UVJ+Ar-:S9jq_1x[M{Rj_NjZMwozV=ROx]t8',
#                         'description': 'Cóndor andino volando en libertad bajo '
#                                        'el cielo azul.\n'
#                                        '\n'
#                                        'Ave grande, con sus alas extendidas.',
#                         'id': '111338952901113942',
#                         'meta': {'focus': {'x': 0.0, 'y': 0.0},
#                                  'original': {'aspect': 1.4985365853658537,
#                                               'height': 1025,
#                                               'size': '1536x1025',
#                                               'width': 1536},
#                                  'small': {'aspect': 1.4974489795918366,
#                                            'height': 392,
#                                            'size': '587x392',
#                                            'width': 587}},
#                         'preview_remote_url': None,
#                         'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/111/338/952/901/113/942/small/4b387b3ef0214284.jpg',
#                         'remote_url': 'https://social.politicaconciencia.org/system/media_attachments/files/111/338/949/320/315/687/original/9cc1cffdc8dbdb7b.jpg',
#                         'text_url': None,
#                         'type': 'image',
#                         'url': 'https://files.mastodon.social/cache/media_attachments/files/111/338/952/901/113/942/original/4b387b3ef0214284.jpg'}],
#  'mentions': [],
#  'poll': None,
#  'reblog': None,
#  'reblogs_count': 0,
#  'replies_count': 0,
#  'sensitive': False,
#  'spoiler_text': '',
#  'tags': [{'name': 'veganism', 'url': 'https://mastodon.social/tags/veganism'},
#           {'name': 'govegan', 'url': 'https://mastodon.social/tags/govegan'},
#           {'name': 'veganismo',
#            'url': 'https://mastodon.social/tags/veganismo'},
#           {'name': 'libertad', 'url': 'https://mastodon.social/tags/libertad'}],
#  'uri': 'https://social.politicaconciencia.org/users/SofiaK/statuses/111338952551568291',
#  'url': 'https://social.politicaconciencia.org/@SofiaK/111338952551568291',
#  'visibility': 'public'}
#
# ---------------
#
# {'account': {'acct': 'Pece@aus.social',
#              'avatar': 'https://files.mastodon.social/cache/accounts/avatars/109/296/611/683/824/782/original/39dffba8a09bd3d0.png',
#              'avatar_static': 'https://files.mastodon.social/cache/accounts/avatars/109/296/611/683/824/782/original/39dffba8a09bd3d0.png',
#              'bot': False,
#              'created_at': '2022-11-04T00:00:00.000Z',
#              'discoverable': True,
#              'display_name': 'Tato Pece',
#              'emojis': [],
#              'fields': [{'name': 'Just my toots:',
#                          'value': '<a '
#                                   'href="https://justmytoots.com/@Pece@aus.social" '
#                                   'rel="nofollow noopener noreferrer" '
#                                   'translate="no" target="_blank"><span '
#                                   'class="invisible">https://</span><span '
#                                   'class="ellipsis">justmytoots.com/@Pece@aus.soci</span><span '
#                                   'class="invisible">al</span></a>',
#                          'verified_at': None},
#                         {'name': 'Secondary account:',
#                          'value': '<span class="h-card" translate="no"><a '
#                                   'href="https://mastodon.social/@PeceK" '
#                                   'class="u-url mention" rel="nofollow '
#                                   'noopener noreferrer" '
#                                   'target="_blank">@<span>PeceK@mastodon.social</span></a></span>',
#                          'verified_at': None},
#                         {'name': 'Pronouns:',
#                          'value': 'He/Him/His',
#                          'verified_at': None},
#                         {'name': 'I respect:',
#                          'value': '♀️🏳️\u200d🌈🏳️\u200d⚧️<a '
#                                   'href="https://aus.social/tags/BLM" '
#                                   'class="mention hashtag" rel="nofollow '
#                                   'noopener noreferrer" '
#                                   'target="_blank">#<span>BLM</span></a>🇺🇦♿🏴\u200d☠️Ⓐ',
#                          'verified_at': None}],
#              'followers_count': 616,
#              'following_count': 415,
#              'group': False,
#              'header': 'https://files.mastodon.social/cache/accounts/headers/109/296/611/683/824/782/original/11eb469b4dc3fa75.png',
#              'header_static': 'https://files.mastodon.social/cache/accounts/headers/109/296/611/683/824/782/original/11eb469b4dc3fa75.png',
#              'id': '109296611683824782',
#              'last_status_at': '2023-11-02',
#              'locked': False,
#              'note': '<p><a href="https://aus.social/tags/VeganForTheAnimals" '
#                      'class="mention hashtag" rel="nofollow noopener '
#                      'noreferrer" '
#                      'target="_blank">#<span>VeganForTheAnimals</span></a> '
#                      '🌱<br>🐄🐖🐓🐑🦃🐎🦓🦒🦏🦍🦌🦊🦇🦁🐼🐻🦂🦈🐝<br>🐺🐬🐫🐨🐦🐢🐘🐗🐕🐐🐌🐈🐇🐆🐅🐒🐃🕷️🦀<br>🐂🐙🐁🐧🐀🐋🐍🐳🐎🦔🐠🐡🐊🐸🐹🐚🐛🐿️🕊️</p><p>Alt '
#                      'text<br>Avatar: Me<br>Header: King of the animals—as '
#                      'thou hast described him—I should rather say king of the '
#                      'beasts, thou being the greatest—because thou hast spared '
#                      'slaying them, in order that they may give thee their '
#                      'children for the benefit of the gullet, of which thou '
#                      'hast attempted to make a sepulchre for all animals; and '
#                      'I would say still more, if it were allowed me to speak '
#                      'the entire truth. Leonardo da Vinci</p>',
#              'statuses_count': 4091,
#              'uri': 'https://aus.social/users/Pece',
#              'url': 'https://aus.social/@Pece',
#              'username': 'Pece'},
#  'card': None,
#  'content': '<p>I am a day late in my timezone but Happy World Vegan Day '
#             'everyone! ☺️❤️🌱🥳🪅🎊🎉</p><p>Celebrations involved buying a box of  '
#             '<a href="https://aus.social/tags/vegan" class="mention hashtag" '
#             'rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>vegan</span></a> <a '
#             'href="https://aus.social/tags/krispykreme" class="mention '
#             'hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>krispykreme</span></a> donuts! 😂 I got '
#             'them from my local <a href="https://aus.social/tags/7eleven" '
#             'class="mention hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>7eleven</span></a>. </p><p>I believe they '
#             'were released in <a href="https://aus.social/tags/Australia" '
#             'class="mention hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>Australia</span></a> on World Vegan Day '
#             'too! </p><p>I have forgotten what non vegan donuts taste like, '
#             'but these were delicious! Highly recommended. Curious if people '
#             'can taste the difference. ☺️</p><p><a '
#             'href="https://aus.social/tags/vegans" class="mention hashtag" '
#             'rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>vegans</span></a> <a '
#             'href="https://aus.social/tags/veganism" class="mention hashtag" '
#             'rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>veganism</span></a> <a '
#             'href="https://aus.social/tags/AnimalRights" class="mention '
#             'hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>AnimalRights</span></a> <a '
#             'href="https://aus.social/tags/veganFood" class="mention hashtag" '
#             'rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>veganFood</span></a> <a '
#             'href="https://aus.social/tags/veganForTheAnimals" class="mention '
#             'hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>veganForTheAnimals</span></a> <a '
#             'href="https://aus.social/tags/GoVegan" class="mention hashtag" '
#             'rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>GoVegan</span></a></p><p>-------------------<br>PS. '
#             'I was going to just post this picture and be done with it, but I '
#             'won\'t be an <a href="https://aus.social/tags/AnnoyingVegan" '
#             'class="mention hashtag" rel="nofollow noopener noreferrer" '
#             'target="_blank">#<span>AnnoyingVegan</span></a> without giving a '
#             'thousand words of backstory as to why these donuts actually make '
#             'me a bit happier than just for the fact that they are vegan, '
#             'donuts, and are edible (all things that excite me very much 😂). '
#             'No, these donuts actually represent a little bit of progress, and '
#             'while I am 99.99% sure it had nothing to do with me, it feels '
#             'nice to imagine and pretend the fact that these donuts are now on '
#             'sale in Australia due to my pestering. So on the bird site, this '
#             'is the exchange I had with Krispy Kreme UK a year and a bit '
#             'ago:</p><p>-Me: "Someone bought Krispy Kreme donuts at the office '
#             "today and I missed out. But it's ok, it was worth it.</p><p>Hey @ "
#             'krispykremeUK, can you tell the Australian division to make vegan '
#             'options? 🌱" </p><p>*Picture of Lisa Simpsons looking at the '
#             'inside of her home while a group of people watch the boxing game '
#             'with stolen cable*</p><p>-Krispykreme: "Oh noooo! What would your '
#             'dream doughnut be? 👀"</p><p>-M: "Thank you so much for your '
#             'response. A vegan Krispy Kreme with Oreo would blow my mind! '
#             '😋😍</p><p>I know us Australians are a bit behind the times but if '
#             'you can give your former colony a gentle kick in the bum, the '
#             'vegans in Australia would much appreciate it! 😂"</p><p>*Gif of '
#             'Homer Simpsons about to boot a judge or barrister in that episode '
#             'where they go to Australia*</p><p>-K: "We\'ll be sure to pass '
#             'your suggestions over to our team 😉"</p><p>-M: "Thank you so '
#             'much! 🌱🐮🐄🐣"</p><p>-M: "The best part is, I would be incredibly '
#             'surprised if (done in a double blind randomised fashion '
#             '👩\u200d🔬🧑\u200d🔬🔬👨\u200d💻), that any person would be able to '
#             'distinguish a Krispy Kreme Donut with or without chicken eggs or '
#             'cow milk. So the taste &amp; that delicious donut will still be '
#             'there!🤣🍩"<br>-------------------</p>',
#  'created_at': '2023-11-02T00:26:32.000Z',
#  'edited_at': None,
#  'emojis': [],
#  'favourites_count': 0,
#  'id': '111338114136044060',
#  'in_reply_to_account_id': None,
#  'in_reply_to_id': None,
#  'language': 'en',
#  'media_attachments': [{'blurhash': 'UFHVI??dIT4nwi.5t8IV4n$|xbX9EJnVW,of',
#                         'description': 'Vegan Krispy Kreme Donuts on top of a '
#                                        'work desk. A keyboard, mouse, screen, '
#                                        'and some books are also present.',
#                         'id': '111338113850721329',
#                         'meta': {'original': {'aspect': 1.52327098738582,
#                                               'height': 2299,
#                                               'size': '3502x2299',
#                                               'width': 3502},
#                                  'small': {'aspect': 1.5218508997429305,
#                                            'height': 389,
#                                            'size': '592x389',
#                                            'width': 592}},
#                         'preview_remote_url': None,
#                         'preview_url': 'https://files.mastodon.social/cache/media_attachments/files/111/338/113/850/721/329/small/620c9b41c90819d2.jpg',
#                         'remote_url': 'https://mediacdn.aus.social/media_attachments/files/111/338/099/099/161/596/original/f9767fafe18e8060.jpg',
#                         'text_url': None,
#                         'type': 'image',
#                         'url': 'https://files.mastodon.social/cache/media_attachments/files/111/338/113/850/721/329/original/620c9b41c90819d2.jpg'}],
#  'mentions': [],
#  'poll': None,
#  'reblog': None,
#  'reblogs_count': 7,
#  'replies_count': 1,
#  'sensitive': False,
#  'spoiler_text': '',
#  'tags': [{'name': 'vegan', 'url': 'https://mastodon.social/tags/vegan'},
#           {'name': 'krispykreme',
#            'url': 'https://mastodon.social/tags/krispykreme'},
#           {'name': '7eleven', 'url': 'https://mastodon.social/tags/7eleven'},
#           {'name': 'australia',
#            'url': 'https://mastodon.social/tags/australia'},
#           {'name': 'vegans', 'url': 'https://mastodon.social/tags/vegans'},
#           {'name': 'veganism', 'url': 'https://mastodon.social/tags/veganism'},
#           {'name': 'animalrights',
#            'url': 'https://mastodon.social/tags/animalrights'},
#           {'name': 'veganfood',
#            'url': 'https://mastodon.social/tags/veganfood'},
#           {'name': 'veganfortheanimals',
#            'url': 'https://mastodon.social/tags/veganfortheanimals'},
#           {'name': 'govegan', 'url': 'https://mastodon.social/tags/govegan'},
#           {'name': 'annoyingvegan',
#            'url': 'https://mastodon.social/tags/annoyingvegan'}],
#  'uri': 'https://aus.social/users/Pece/statuses/111338113757677381',
#  'url': 'https://aus.social/@Pece/111338113757677381',
#  'visibility': 'public'}
#
# ---------------

# %% [markdown]
# ## 2. Inspecting metadata

# %% [markdown]
# The toots come with a complex metadata structure. JSON represents this as nested dictionaries and you can access information using the respective keys. **Inspect the metadata structure and reflect how the information is relevant for your analysis.**
#
# If you use keys such as *language*, *sensitive*, or *bot* for filtering the posts, you should **check in the documentation how this information is determined.** It might be the case that some information is missing, i.e., some keys are not necessarily available for all toots.

# %%
import html2text
posts = toots
print("Metadata for toot:")
print(posts[0].keys())
print()

# The json format is a nested dictionary
print("Metadata for user account which posted toot:")
print(posts[0]["account"].keys())
print()
      
print(html2text.html2text(posts[2]["content"]))
# Out:
# Metadata for toot:
# dict_keys(['id', 'created_at', 'in_reply_to_id', 'in_reply_to_account_id', 'sensitive', 'spoiler_text', 'visibility', 'language', 'uri', 'url', 'replies_count', 'reblogs_count', 'favourites_count', 'edited_at', 'content', 'reblog', 'account', 'media_attachments', 'mentions', 'tags', 'emojis', 'card', 'poll'])
#
# Metadata for user account which posted toot:
# dict_keys(['id', 'username', 'acct', 'display_name', 'locked', 'bot', 'discoverable', 'group', 'created_at', 'note', 'url', 'uri', 'avatar', 'avatar_static', 'header', 'header_static', 'followers_count', 'following_count', 'statuses_count', 'last_status_at', 'emojis', 'fields'])
#
# What Is Veganism? And How Is It Different To A Plant-Based Diet?
# [#plantbased](https://veganism.social/tags/plantbased)
# [#diet](https://veganism.social/tags/diet)
# [#veganism](https://veganism.social/tags/veganism)
# [#GoVegan](https://veganism.social/tags/GoVegan)
# [https://plantbasednews.org/culture/ethics/what-is-
# veganism/](https://plantbasednews.org/culture/ethics/what-is-veganism/)

# %% [markdown]
# ## 3. Getting around the limit
#
# For every request, you can only access at most 40 toots. To get around this, we need to look at the unique identifier (id) of the toot. Toots that have been created later, have a larger id.

# %%
num_toots = 200
results = []

# Be careful, if this expression never evaluates to False, 
# you will be stuck in an endless loop

while len(results) < num_toots:
    
    # Send query
    r = requests.get(URL, params=params)
    toots = json.loads(r.text)  # saves to json object
    
    # If we do not get any results, we leave the loop (although we might have collected less than num_toots)
    if len(toots) == 0: 
        break
    
    for toot in toots: 
        results.append(toot)
        if len(results) == num_toots:
            break
            
        
    max_id = toots[-1]['id'] 
    # We add the parameter max_id to our request
    params['max_id'] = max_id
    
    print("Next request looking at toots with ids smaller than: ")
    print(max_id)
    
    
print(results[199:200])
# Out:
# Next request looking at toots with ids smaller than:
# 111287369327270860
# Next request looking at toots with ids smaller than:
# 111173953504503449
# Next request looking at toots with ids smaller than:
# 111079964383007656
# Next request looking at toots with ids smaller than:
# 111034361527215691
# Next request looking at toots with ids smaller than:
# 110961547458716493
# [{'id': '110961547458716493', 'created_at': '2023-08-27T12:20:46.725Z', 'in_reply_to_id': None, 'in_reply_to_account_id': None, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'nl', 'uri': 'https://mastodon.social/users/itsveganjim/statuses/110961547458716493', 'url': 'https://mastodon.social/@itsveganjim/110961547458716493', 'replies_count': 0, 'reblogs_count': 9, 'favourites_count': 13, 'edited_at': None, 'content': '<p><a href="https://mastodon.social/tags/melaniejoy" class="mention hashtag" rel="tag">#<span>melaniejoy</span></a> <a href="https://mastodon.social/tags/veganism" class="mention hashtag" rel="tag">#<span>veganism</span></a> <a href="https://mastodon.social/tags/carnism" class="mention hashtag" rel="tag">#<span>carnism</span></a> <a href="https://mastodon.social/tags/speciesism" class="mention hashtag" rel="tag">#<span>speciesism</span></a> <a href="https://mastodon.social/tags/books" class="mention hashtag" rel="tag">#<span>books</span></a></p>', 'reblog': None, 'application': {'name': 'Toot!', 'website': 'https://toot.c3.cx/'}, 'account': {'id': '108431110488823039', 'username': 'itsveganjim', 'acct': 'itsveganjim', 'display_name': 'itsveganjim', 'locked': False, 'bot': False, 'discoverable': False, 'group': False, 'created_at': '2022-06-06T00:00:00.000Z', 'note': '<p>🕊 🌍 <a href="https://mastodon.social/tags/animalrights" class="mention hashtag" rel="tag">#<span>animalrights</span></a> <a href="https://mastodon.social/tags/endcarnism" class="mention hashtag" rel="tag">#<span>endcarnism</span></a></p>', 'url': 'https://mastodon.social/@itsveganjim', 'uri': 'https://mastodon.social/users/itsveganjim', 'avatar': 'https://files.mastodon.social/accounts/avatars/108/431/110/488/823/039/original/34b3d63f16db11a7.png', 'avatar_static': 'https://files.mastodon.social/accounts/avatars/108/431/110/488/823/039/original/34b3d63f16db11a7.png', 'header': 'https://files.mastodon.social/accounts/headers/108/431/110/488/823/039/original/1c051bcf293b34c5.png', 'header_static': 'https://files.mastodon.social/accounts/headers/108/431/110/488/823/039/original/1c051bcf293b34c5.png', 'followers_count': 588, 'following_count': 149, 'statuses_count': 2989, 'last_status_at': '2023-11-02', 'noindex': True, 'emojis': [], 'roles': [], 'fields': []}, 'media_attachments': [{'id': '110961546612213782', 'type': 'image', 'url': 'https://files.mastodon.social/media_attachments/files/110/961/546/612/213/782/original/841e48b0772bb838.jpg', 'preview_url': 'https://files.mastodon.social/media_attachments/files/110/961/546/612/213/782/small/841e48b0772bb838.jpg', 'remote_url': None, 'preview_remote_url': None, 'text_url': None, 'meta': {'original': {'width': 2160, 'height': 3840, 'size': '2160x3840', 'aspect': 0.5625}, 'small': {'width': 360, 'height': 640, 'size': '360x640', 'aspect': 0.5625}}, 'description': None, 'blurhash': 'UXM6^vt7D*tQ?uofRjj[01Rkt6V[t7fkf6j['}], 'mentions': [], 'tags': [{'name': 'melaniejoy', 'url': 'https://mastodon.social/tags/melaniejoy'}, {'name': 'veganism', 'url': 'https://mastodon.social/tags/veganism'}, {'name': 'carnism', 'url': 'https://mastodon.social/tags/carnism'}, {'name': 'speciesism', 'url': 'https://mastodon.social/tags/speciesism'}, {'name': 'books', 'url': 'https://mastodon.social/tags/books'}], 'emojis': [], 'card': None, 'poll': None}]

# %% [markdown]
# You can additionally use the "created_at" timestamp to limit your toots to a certain time period.

# %% [markdown]
# ## Reproducibility
#
# If someone else crawls toots using your code at a later time, they will retrieve a different set because Mastodon always returns the most recent toots first.
#
# To avoid this, you should provide a list of ids of your crawled toots.

# %%
ids = [toot["id"] for toot in results]
# You can specifiy the id of the toot you want to crawl
params = {'id': ids[0]}

r = requests.get(URL, params=params)
toots = json.loads(r.text)  # saves to json object

print(toots[0]["content"] == results[0]["content"])
# Out:
# True

# %% [markdown]
# **How do you need to adjust the above code to write a function that yields the correct toots when given a list of ids?** Keep in mind that toots might have been deleted by a user in the meantime. In that case, it is impossible to retrieve the same set of toots. You need to make sure that the code deals with this exception and outputs an appropriate warning.

# %% [markdown]
# ## 4. Saving results
#
# We have two options for saving the results.
# 1. We can select specific attributes and save them as a tsv-file.
# 2. If we do not want to decide yet which attributes we need, we can simply dump the whole JSON result to a file and process it later.
#
# **Make sure that you understand the code below. Open the result files in an editor and compare the differences.**

# %%
# Collect the results
toots_as_json =[]
toots_as_text =[]

for toot in toots: 
    # TODO: You might want to apply some filtering based on metadata here
    
    # Option 1: only keep selected attributes
    text= html2text.html2text(toot["content"])
    keep = str(toot["created_at"]) + "\t" + str(toot["id"]) + str(toot["account"]["id"]) + "\t" + text
    toots_as_text.append(keep)  
    
    # Option 2: keep everything and process later
    toots_as_json.append(toot)
    
# Write them to a file
csv_file = "../results/mastodon_search_results/results_veganism.csv"
json_file = "../results/mastodon_search_results/results_veganism.json"

with open(csv_file, 'w',encoding="utf-8") as outfile:
    csv_header = "Created at\tUser\tText\n"
    outfile.write(csv_header)
    outfile.write("\n".join(toots_as_text))

with open(json_file, 'w') as outfile:
    json.dump(toots_as_json, outfile)
